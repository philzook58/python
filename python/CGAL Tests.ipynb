# %%
import CGAL

# %%
help(CGAL)
# Out:
# Help on package CGAL:
#
# NAME
#     CGAL
#
# PACKAGE CONTENTS
#     CGAL_AABB_tree
#     CGAL_Advancing_front_surface_reconstruction
#     CGAL_Alpha_shape_2
#     CGAL_Box_intersection_d
#     CGAL_Convex_hull_2
#     CGAL_HalfedgeDS
#     CGAL_Interpolation
#     CGAL_Kernel
#     CGAL_Mesh_2
#     CGAL_Mesh_3
#     CGAL_Point_set_processing_3
#     CGAL_Polygon_mesh_processing
#     CGAL_Polyhedron_3
#     CGAL_Polyline_simplification_2
#     CGAL_Spatial_searching
#     CGAL_Triangulation_2
#     CGAL_Triangulation_3
#     CGAL_Voronoi_diagram_2
#     _CGAL_AABB_tree
#     _CGAL_Advancing_front_surface_reconstruction
#     _CGAL_Alpha_shape_2
#     _CGAL_Box_intersection_d
#     _CGAL_Convex_hull_2
#     _CGAL_HalfedgeDS
#     _CGAL_Interpolation
#     _CGAL_Kernel
#     _CGAL_Mesh_2
#     _CGAL_Mesh_3
#     _CGAL_Point_set_processing_3
#     _CGAL_Polygon_mesh_processing
#     _CGAL_Polyhedron_3
#     _CGAL_Polyline_simplification_2
#     _CGAL_Spatial_searching
# ...

# %%
from CGAL import CGAL_Kernel

# %%
help(CGAL_Kernel)
# Out:
# Help on module CGAL.CGAL_Kernel in CGAL:
#
# NAME
#     CGAL.CGAL_Kernel
#
# DESCRIPTION
#     # This file was automatically generated by SWIG (http://www.swig.org).
#     # Version 3.0.10
#     #
#     # Do not make changes to this file unless you know what you are doing--modify
#     # the SWIG interface file instead.
#
# CLASSES
#     builtins.object
#         Bbox_2
#         Bbox_3
#         Direction_2
#         Direction_3
#         Iso_cuboid_3
#         Iso_rectangle_2
#         Line_2
#         Line_3
#         Null_vector
#         Object
#         Origin
#         Plane_3
#         Point_2
#         Point_3
#         Polygon_2
#         Polygon_2_Edge_const_circulator
#         Polygon_2_Edge_const_iterator
#         Polygon_2_Vertex_circulator
#         Polygon_2_Vertex_iterator
#         Ray_2
#         Ray_3
#         Ref_int
#         Segment_2
#         Segment_3
#         Sphere_3
#         Tetrahedron_3
#         Triangle_2
#         Triangle_3
#         Vector_2
# ...

# %%
from CGAL.CGAL_Kernel import Point_2

# %%
p1 = Point_2(1,2)
p2 = Point_2(1,3)

# %%
help(p1)
# Out:
# Help on Point_2 in module CGAL.CGAL_Kernel object:
#
# class Point_2(builtins.object)
#  |  Methods defined here:
#  |
#  |  __add__(self, arg2)
#  |
#  |  __del__ lambda self
#  |
#  |  __eq__(self, *args)
#  |      Return self==value.
#  |
#  |  __ge__(self, p)
#  |      Return self>=value.
#  |
#  |  __getattr__ lambda self, name
#  |
#  |  __gt__(self, p)
#  |      Return self>value.
#  |
#  |  __iadd__(self, arg2)
#  |
#  |  __init__(self, *args)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __isub__(self, arg2)
#  |
#  |  __le__(self, p)
#  |      Return self<=value.
#  |
#  |  __lt__(self, p)
#  |      Return self<value.
#  |
#  |  __ne__(self, p)
#  |      Return self!=value.
#  |
#  |  __repr__ = _swig_repr(self)
#  |
#  |  __setattr__ lambda self, name, value
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  __sub__(self, *args)
#  |
#  |  __swig_destroy__ = delete_Point_2(...)
#  |
#  |  bbox(self, *args)
#  |
# ...

# %%
from CGAL.CGAL_Kernel import Line_2

# %%
l1 = Line_2(p1,p2)

# %%
print(l1)
print(p1)
# Out:
# -1 0 1
# 1 2

# %%
help(l1)
# Out:
# Help on Line_2 in module CGAL.CGAL_Kernel object:
#
# class Line_2(builtins.object)
#  |  Methods defined here:
#  |
#  |  __del__ lambda self
#  |
#  |  __eq__(self, p)
#  |      Return self==value.
#  |
#  |  __getattr__ lambda self, name
#  |
#  |  __init__(self, *args)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ne__(self, p)
#  |      Return self!=value.
#  |
#  |  __repr__ = _swig_repr(self)
#  |
#  |  __setattr__ lambda self, name, value
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  __swig_destroy__ = delete_Line_2(...)
#  |
#  |  a(self)
#  |
#  |  b(self)
#  |
#  |  c(self)
#  |
#  |  deepcopy(self, *args)
#  |
#  |  direction(self, *args)
#  |
#  |  has_on(self, c)
#  |
#  |  has_on_negative_side(self, c)
#  |
#  |  has_on_positive_side(self, c)
#  |
#  |  is_degenerate(self)
#  |
#  |  is_horizontal(self)
#  |
#  |  is_vertical(self)
#  |
#  |  opposite(self, *args)
#  |
#  |  oriented_side(self, c)
#  |
# ...

# %%
l1.has_on(p1)
p3 = Point_2(1,5)

# %%
l1.has_on(p3)
# Out:
# True

# %% [markdown]
# get vectors from subtraction. Makes sense.

# %%
p1 - p2
# Out:
# <CGAL.CGAL_Kernel.Vector_2; proxy of <Swig Object of type 'Vector_2 *' at 0x10bdc4d50> >

# %%
import CGAL.CGAL_HalfedgeDS as he

# %%
help(he)
# Out:
# Help on module CGAL.CGAL_HalfedgeDS in CGAL:
#
# NAME
#     CGAL.CGAL_HalfedgeDS
#
# DESCRIPTION
#     # This file was automatically generated by SWIG (http://www.swig.org).
#     # Version 3.0.10
#     #
#     # Do not make changes to this file unless you know what you are doing--modify
#     # the SWIG interface file instead.
#
# CLASSES
#     builtins.object
#         HDS_Face_handle
#         HDS_Face_iterator
#         HDS_Halfedge_handle
#         HDS_Halfedge_iterator
#         HDS_Vertex_handle
#         HDS_Vertex_iterator
#         HalfedgeDS
#         HalfedgeDS_decorator
#         HalfedgeDS_modifier
#
#     class HDS_Face_handle(builtins.object)
#      |  Methods defined here:
#      |
#      |  __del__ lambda self
#      |
#      |  __eq__(self, p)
#      |      Return self==value.
#      |
#      |  __getattr__ lambda self, name
#      |
#      |  __hash__(self)
#      |      Return hash(self).
#      |
#      |  __init__(self)
# ...
